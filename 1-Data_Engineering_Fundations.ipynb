# %% [markdown]
# # 1-Data_Engineering_Fundations:

# %% [markdown]
# ## Data engineering ecosystem:
# - Analytics (Detrive insights from raw data):
#     - Business Intelligence
#     - SEO analytics
#     - Usage metrics
# - Data Science (Machine learning pipelines):
#     - Recommendation system
#     - Fraud detection
#     - LLMS
# - Streaming (Real-time data transferring systems):
#     - Video streamling
#     - Social media
#     - Video conferencing

# %% [markdown]
# ## Tools and Terms:
# - 1 Data Sourcing:
#     - Finding the data you need
# - 2 Data Storage:
#     - Storing the data in the right format
# - 3 Data Processing:
#     - Processing the data to arrive at the desired outcome
# - 4 Data Orchestration:
#     - Maning data pipelines all in one place

# %% [markdown]
# ## Data Sourcing Tools:
# - Python scripts
# - Airbyte
# - Fivetran
# - Airflow
#
# ## Data Storage and Management:
# - Databases
# - Data lake
# - Data warehouse
# - Filesystems
#
# ## Data processing:
# - Python scripts
# - BigQuery
# - Apache Spark
# - Apache Beam
# - Streaming (Kafka/PubSub)
#
# ## Data Orchestratos:
# - Apache Airflow
# - Kestra
# - Prefect

# %% [markdown]
# ## What's in the Course ?
# - Learing Data Engineering Concepts
# - Using Google Cloud Platform tools
#
# ## Data Sourcing:
#     - Finding datasets
#     - Sourcing datasets
#
# ## GCP Storage tools:
# - Google Cloud Storage
# - Big query
#
# ## GCP Data Processing Tools:
# - Dataproc
# - Dataflow
# - Pub/Sub
# - Cloud Composer
#
# ## Projects:
# - Batch processing
# - Stream processing

# %% [markdown]
# ## Service Accounts:
# - IAM settings
# - Your personal e-mail
